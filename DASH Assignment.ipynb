# %%
pip install dash==1.11.0
# Out:
# Collecting dash==1.11.0
#   Downloading dash-1.11.0.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 1.4 MB/s eta 0:00:011
# Requirement already satisfied: Flask>=1.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from dash==1.11.0) (1.1.1)
# Collecting flask-compress
#   Downloading Flask-Compress-1.4.0.tar.gz (6.0 kB)
# Requirement already satisfied: plotly in /opt/anaconda3/lib/python3.7/site-packages (from dash==1.11.0) (4.6.0)
# Collecting dash_renderer==1.4.0
#   Downloading dash_renderer-1.4.0.tar.gz (1.2 MB)
#      |████████████████████████████████| 1.2 MB 3.0 MB/s eta 0:00:01
# Collecting dash-core-components==1.9.1
#   Downloading dash_core_components-1.9.1.tar.gz (3.4 MB)
#      |████████████████████████████████| 3.4 MB 6.6 MB/s eta 0:00:01
# Collecting dash-html-components==1.0.3
#   Downloading dash_html_components-1.0.3.tar.gz (187 kB)
#      |████████████████████████████████| 187 kB 22.5 MB/s eta 0:00:01
# Collecting dash-table==4.6.2
#   Downloading dash_table-4.6.2.tar.gz (1.8 MB)
#      |████████████████████████████████| 1.8 MB 26.1 MB/s eta 0:00:01     |███████████████████████████▉    | 1.5 MB 26.1 MB/s eta 0:00:01
# Requirement already satisfied: future in /opt/anaconda3/lib/python3.7/site-packages (from dash==1.11.0) (0.18.2)
# Requirement already satisfied: Werkzeug>=0.15 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.11.0) (1.0.0)
# Requirement already satisfied: click>=5.1 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.11.0) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.11.0) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /opt/anaconda3/lib/python3.7/site-packages (from Flask>=1.0.2->dash==1.11.0) (2.11.1)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.11.0) (1.14.0)
# Requirement already satisfied: retrying>=1.3.3 in /opt/anaconda3/lib/python3.7/site-packages (from plotly->dash==1.11.0) (1.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.7/site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash==1.11.0) (1.1.1)
# Building wheels for collected packages: dash, flask-compress, dash-renderer, dash-core-components, dash-html-components, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.11.0-py3-none-any.whl size=72525 sha256=23a8d9a418b00004d5fd56f7c70cd1f3eca67f6e471280540bb1a29012a604fb
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/2b/91/42/926cefc4e54c992a827bec9216f3f145278ee4e5d165a70dfb
#   Building wheel for flask-compress (setup.py) ... done
#   Created wheel for flask-compress: filename=Flask_Compress-1.4.0-py3-none-any.whl size=3711 sha256=45cbf6e9836bb50734409f03bc88742fb17bb205accd838ef1d9244da3a8eb5e
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/1f/42/7e/72241359a71f5f9d4e97f55e6d4ac99939efaec4e1fa7b23b8
#   Building wheel for dash-renderer (setup.py) ... done
#   Created wheel for dash-renderer: filename=dash_renderer-1.4.0-py3-none-any.whl size=1164166 sha256=8bb39099ad4cda1628de84e31451a8e239c5af1081c01cb2f4f0ecb65c2469ea
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/54/ff/2e/a92792032df69c50d27e17ee341ec4d18f8c9522b9bd188780
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.9.1-py3-none-any.whl size=3407354 sha256=f6cf8c14caab136893f85f4ac408a27e87742db4625015138f4a4c7067732fae
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/08/39/36/d9a493ce95806f487af1b84b7e5a2f1f756281ef6af31fb866
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.0.3-py3-none-any.whl size=427304 sha256=bc183daedad30df39ee1070b6a9016f77c972b29b092f4678e61f7b233478c64
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/36/34/f9/c3d147461b28467d5bbd14d255be66f6728a1580ff9fbebece
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.6.2-py3-none-any.whl size=1769390 sha256=b3dcc01f68dfec2d9399448d5f7a4328619417a530ba3381591eda1a1b3f3c92
#   Stored in directory: /Users/anirudh/Library/Caches/pip/wheels/ef/a3/4e/79f9a24e4f7481a680c71ea27b542dc8629d3090733f4e50cf
# Successfully built dash flask-compress dash-renderer dash-core-components dash-html-components dash-table
# Installing collected packages: flask-compress, dash-renderer, dash-core-components, dash-html-components, dash-table, dash
# Successfully installed dash-1.11.0 dash-core-components-1.9.1 dash-html-components-1.0.3 dash-renderer-1.4.0 dash-table-4.6.2 flask-compress-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd

# Uses an External Stylesheet
# Use a css file from your GitHub Pages site 
external_stylesheets = ['https://dv.github.io/learn.css']

# Creates the app to instantiate the content for the Dashboard and use the external_stylesheets
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

# Use a csv dataset from a repository in your GitHub account. Use the Raw URL to expose the data to the Python dataframe

df3 = pd.read_csv('https://raw.githubusercontent.com/gjanirudh2810/data/master/cereal.csv')

colors = {
    'background': '#E6E6FA'
}

# Custom function used to generate a data table from a dataframe
def generate_table(dataframe, max_rows=11):
    return html.Table([
        html.Thead(
            html.Tr([html.Th(col) for col in dataframe.columns])
        ),
        html.Tbody([
            html.Tr([
                html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
            ]) for i in range(min(len(dataframe), max_rows))
        ])
    ])



# Add content to the app layout
# Begin all content DIV
app.layout=html.Div(style={'backgroundColor': colors['background']},children=[
    # Add your HTML tags to the content - notice a comma is added between HTML elements
    html.H1('Week 10 Assignment'),
    

    
    # Begin of DIV surrounding both Tables
    html.Div([ 
        
        
    # Begin of First Table
    html.Table(style={'width':'100%'},
               # Begin of Table children
               children=[
                   #######################################################################
                   # Begin of First Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Th
                         
                         html.Th(style={'width':'30%'},
                             # Begin Th children
                             children=[
                                 html.H3('Cereals')
                             # End of Th children   
                             ]
                         
                         # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         # Begin of Th
                         html.Th(style={'width':'70%'},
                             # Begin of Th children
                             children=[
                                 html.H3(' ')
                             # End of Th children    
                             ]
                         
                         # End of Th
                         )
                         
                     # End of Tr children    
                     ]
                 # End of First Tr - Notice a comma is placed here to separate the next Tr
                 ),
                 #########################################################################
                 # Begin of Second Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Td
                         html.Td(
                             # Begin Td children
                             children=[
                                    # Display bar graph
                                    dcc.Graph(
                                    id='example-graph',
                                    figure={
                                        'data': [
                                            {'x': ['All-Bran with Extra Fiber', 'Shredded Wheat n Bran', 'Shredded Wheat spoon size','100% Bran','Shredded Wheat'], 'y': [50,90,90,70,80], 'type': 'bar'},
                                           
                                        ],
                                        'layout': {
                                            'title': 'Top 5 Cereals and Calories'
                                        }
                                    }
                                # End of Chart 1
                                )
                              # End of Td children   
                             ]
                         
                         # End of Td - Notice a comma is placed here to separate the next Th
                         ),
                         
                         html.Td(
                             # Begin Td children
                             children=[
                                    # Display a simple line graph
                                    dcc.Graph(
                                        id='g1', 
                                        figure={'data': [{'x': ['All-Bran with Extra Fiber', 'Shredded Wheat n Bran', 'Shredded Wheat spoon size','100% Bran','Shredded Wheat'], 'y': [4, 3, 3,4,2], 'type': 'bar'},
                                                ], 'layout': {'title': 'Top 5 Cereal vs protein'}})
                             # End of Td children   
                             ]
                         
                         # End of Td - Notice a comma is placed here to separate the next Th
                         ),
                         
                     # End of Tr children    
                     ]
                 # End of Tr
                 )     
                #########################################################################                   
               #End of Table Children    
               ]
              # End of First Table - Notice a comma is placed here to separate the next Table
              ),
        
        # Begin of Second Table
    html.Table(style={'width':'100%'},
               children=[
                 #######################################################################
                 # Begin First Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Th
                         html.Th(style={'width':'30%'},
                             # Begin Th children
                             children=[
                                 html.H3('TOP 10 CEREALS')
                             # End of Th children   
                             ]
                         
                         # End of Th - Notice a comma is placed here to separate the next Th
                         ),
                         
                            
                     ]
                 # End of First Tr
                 ),
                   
                ######################################################################
                # Begin of Second Tr
                 html.Tr(
                     #Begin Tr children
                     children=[
                         # Begin Td
                         
                         # Begin of Td
                        
                         
                         # Begin of Td
                         html.Td(
                             # Begin of Td children
                             children=[
                                    # Execute custom generate_table function and display data
                                    # Use data from dataframe df2
                                    generate_table(df3.nlargest(10,'rating'))
                             # End of Td children    
                             ]
                         # End of Td
                         )
                         
                         
                     # End of Tr children    
                     ]
                 # End of Second Tr
                 )     
                   
                   
               
               #######################################################################
               #End of Table Children    
               ]
              #########################################################################################
              # End of Second Table - Notice a comma is placed here to separate the next Content
              ),
        
        
    
    #########################################################################################   
    
              #########################################################################################
              # End of Second Table - Notice a comma is placed here to separate the next Content
            
   
        
        
    # End of DIV surrounding both Tables
    ]),
               
# End of all content DIV
])

# Run the app on the web server
if __name__ == '__main__':
    # Set debug to False. Some configurations are not setup for Debug
    app.run_server(debug=False)


# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Apr/2020 21:18:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 21:18:14] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Apr/2020 21:18:14] "GET /_dash-dependencies HTTP/1.1" 200 -
